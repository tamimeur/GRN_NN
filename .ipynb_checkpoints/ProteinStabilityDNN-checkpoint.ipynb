# %%
import time
import numpy as np
from matplotlib import pyplot as plt
from keras.utils import np_utils
import keras.callbacks as cb
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.optimizers import RMSprop, SGD, Adam, Nadam
from keras.datasets import mnist
from keras.layers import Merge
from keras.regularizers import l1, l2, activity_l2
from keras.layers.convolutional import Convolution1D, MaxPooling1D
import random
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing
from sklearn.decomposition import PCA
import scipy.stats as stats
import seaborn as sea
import plotly.plotly as py

# %% [markdown]
# # Read in two datasets

# %% [markdown]
# #### Metrics dataframe contains Rosetta metrics associated with protein sequences
#
# #### Data_out dataframe contains the measured stability output associated with each protein sequence

# %%
metrics = pd.read_excel('GJR_design_metrics_161227.xls',header=0)
data_out = pd.read_excel('GJR_data_simplified_161227.xls',header=0,parse_cols="A,P")

# %%
metrics.head()
# Out:
#    AlaCount  SCORE:  abd50_mean  abd50_min  abego_res_profile  \
# 0         5  SCORE:    0.562854      0.252           0.366986
# 1         3  SCORE:    0.501488      0.197           0.310619
# 2         5  SCORE:    0.565878      0.378           0.300949
# 3         4  SCORE:    0.630659      0.223           0.262549
# 4         4  SCORE:    0.427780      0.122           0.313464
#
#    abego_res_profile_penalty  avg_all_frags  avg_best_frag     bb  \
# 0                  -0.033633       1.858251       0.446736 -0.422
# 1                  -0.067378       1.616273       0.388597 -0.396
# 2                  -0.036494       1.682794       0.340376 -0.370
# 3                  -0.040904       1.751651       0.353094 -0.419
# 4                  -0.049119       1.865065       0.415155 -0.312
#
#    buried_minus_exposed      ...        ssc50_min  sum_best_frags  \
# 0              3120.779      ...           -3.442         14.7423
# ...

# %%
data_out.head()
# Out:
#                     name  stability
# 0         EEHEE_0001.pdb   0.057998
# 1      EEHEE_0001.pdb_hp  -0.559243
# 2  EEHEE_0001.pdb_random   0.552774
# 3         EEHEE_0002.pdb  -0.232476
# 4      EEHEE_0002.pdb_hp  -0.380805

# %% [markdown]
# #### Cleaning up metrics 'name' column and merging with data_out on 'name'

# %%
metrics['oldname'] = metrics['name']
data_out['name'] = data_out['name'].map(lambda x: str(x))
metrics['name'] = metrics['oldname'].map(lambda x: str(x)[:-10]+".pdb")
met_colnames = metrics.columns.tolist()
met_colnames.remove(u'name')
met_colnames.insert(0, u'name')
metrics = metrics[met_colnames]
merged_left = pd.merge(left=metrics,right=data_out, how='inner', on='name')
merged_left.head()
# Out:
#              name  AlaCount  SCORE:  abd50_mean  abd50_min  abego_res_profile  \
# 0  EEHEE_0001.pdb         5  SCORE:    0.562854      0.252           0.366986
# 1  EEHEE_0002.pdb         3  SCORE:    0.501488      0.197           0.310619
# 2  EEHEE_0003.pdb         5  SCORE:    0.565878      0.378           0.300949
# 3  EEHEE_0004.pdb         4  SCORE:    0.630659      0.223           0.262549
# 4  EEHEE_0005.pdb         4  SCORE:    0.427780      0.122           0.313464
#
#    abego_res_profile_penalty  avg_all_frags  avg_best_frag     bb    ...      \
# 0                  -0.033633       1.858251       0.446736 -0.422    ...
# 1                  -0.067378       1.616273       0.388597 -0.396    ...
# 2                  -0.036494       1.682794       0.340376 -0.370    ...
# 3                  -0.040904       1.751651       0.353094 -0.419    ...
# 4                  -0.049119       1.865065       0.415155 -0.312    ...
#
# ...

# %% [markdown]
# #### More cleaning - removing columns with no actual values

# %%
# %matplotlib inline
new_merged = merged_left.drop(['SCORE:','abd50_mean','abd50_min',
                               'buried_np_AFILMVWY','buried_np_AFILMVWY_per_res','oldname','description',
                              'dssp'],axis=1)

print(new_merged.columns)

#more cleaning needs to be done. 
#Remove rows and columns with a high percentage of NaN's
# Out:
# Index([u'name', u'AlaCount', u'abego_res_profile',
#        u'abego_res_profile_penalty', u'avg_all_frags', u'avg_best_frag', u'bb',
#        u'buried_minus_exposed', u'buried_np', u'buried_np_per_res',
#        ...
#        u'sum_best_frags', u'total_score', u'tryp_cut_sites', u'two_core_each',
#        u'unsat_hbond', u'unsat_hbond2', u'worst6frags', u'worstfrag',
#        u'yhh_planarity', u'stability'],
#       dtype='object', length=106)

# %% [markdown]
# #### What does our output data look like?

# %%
y, x, _ = plt.hist(new_merged['stability'])
print y.max()

#go through and calculate the max histogram value of each column,
#if the max bin holds > 65% of the data, then eliminate that column 
#for lack of variability
#continue cleaning data by dropping NaNs appropriately
# Out:
# 4496.0

# %% [markdown]
# clean_df = new_merged
# clean_df.head()

# %%
clean_df = new_merged
clean_df = clean_df.set_index('name')
clean_df.head()
#shuffle the dataframe here
clean_df = clean_df.sample(frac=1)

# %% [markdown]
# #### Cleaning and Formatting input_df, the dataframe for our DNN metrics input (these should be numbers only)

# %%
input_df = clean_df
#input_df = input_df.drop(['stability','sequence'],axis=1)
input_df = input_df.drop(['sequence'],axis=1)
input_df = input_df.drop(input_df.columns[(~input_df.isnull()).sum() < 16000], axis=1)
input_df.head()
# Out:
#                     AlaCount  abego_res_profile  abego_res_profile_penalty  \
# name
# EHEE_rd2_1152.pdb          1           0.241352                  -0.041727
# EEHEE_rd3_0082.pdb         4           0.431643                  -0.020755
# HEEH_0032.pdb              3           0.321478                  -0.036379
# HHH_rd2_0112.pdb           5           0.279554                  -0.016085
# EHEE_0603.pdb              1           0.286568                  -0.029856
#
#                     avg_all_frags  avg_best_frag     bb  buried_minus_exposed  \
# name
# EHEE_rd2_1152.pdb        1.480996       0.363100 -0.431              3227.613
# EEHEE_rd3_0082.pdb       1.460127       0.317620 -0.355              3546.608
# HEEH_0032.pdb            1.202431       0.254297 -0.149              3663.000
# HHH_rd2_0112.pdb         0.812459       0.180560 -0.044              3568.377
# EHEE_0603.pdb            1.374865       0.335347 -0.399              3151.085
#
# ...

# %% [markdown]
# #### Check if there are any nan values

# %%
input_df.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Quick view of the input data, input_df

# %%
input_df.hist(figsize=(30, 25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x14926ff10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1592d24d0>]], dtype=object)

# %% [markdown]
# #### Rescaling input data to have mean 0 and variance 1 - for efficient backprop (training)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

new_input_df = scaler.fit_transform(input_df)
new_input_df = pd.DataFrame(data=new_input_df, index=input_df.index, columns=input_df.columns)

X_data = input_df.iloc[:, :-1].values
Y_data = input_df.iloc[:, -1:].values

#new_input_df = scaler.fit_transform(X_data)
#print new_input_df
# X_data = new_input_df.iloc[:, :-1].values
# Y_data = new_input_df.iloc[:, -1:].values

print X_data
print "\n",Y_data

new_input_df.hist(figsize=(30, 25))
#new_input_df
# print X_data
# pca = PCA(n_components=80)
# pca.fit(X_data)
# X_pca = pca.transform(X_data)
# #pca.fit_transform(X_data)
# #print(pca.explained_variance_ratio_)
# print "\n",X_pca
# Out:
# [[ 1.          0.24135215 -0.0417268  ...,  4.4836      0.9198      0.        ]
#  [ 4.          0.43164288 -0.02075488 ...,  4.2794      0.8215      0.1       ]
#  [ 3.          0.32147844 -0.03637889 ...,  3.116       0.6154      0.        ]
#  ...,
#  [ 3.          0.28577302 -0.01459003 ...,  2.1558      0.4114      0.029     ]
#  [ 4.          0.33990646 -0.03598394 ...,  4.4885      1.2065      0.109     ]
#  [ 6.          0.34557189 -0.02513611 ...,  4.2667      0.8343      0.        ]]
#
# [[ 0.80902948]
#  [-0.42084996]
#  [ 0.03984274]
#  ...,
#  [ 1.37739088]
#  [-0.08660979]
#  [ 1.17646535]]
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x16f933610>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x17525bb90>]], dtype=object)

# %% [markdown]
# #### Eliminating columns with lack of variability - they won't provide useful information for our NN

# %%
new_input_df.var()
# Out:
# AlaCount                      0.026587
# abego_res_profile             0.017268
# abego_res_profile_penalty     0.017995
# avg_all_frags                 0.022359
# avg_best_frag                 0.006673
# bb                            0.094587
# buried_minus_exposed          0.020127
# buried_np                     0.028087
# buried_np_per_res             0.016254
# buried_over_exposed           0.011345
# cavity_volume                 0.011828
# chymo_cut_sites               0.031069
# chymo_with_LM_cut_sites       0.022017
# contact_all                   0.022537
# contact_core_SASA             0.022303
# contact_core_SCN              0.021587
# contig_not_hp_avg             0.008930
# contig_not_hp_avg_norm        0.011249
# contig_not_hp_internal_max    0.011952
# contig_not_hp_max             0.015004
# degree                        0.017054
# dslf_fa13                     0.000000
# dslf_quality_check            0.001423
# entropy                       0.000000
# ...

# %% [markdown]
# #### Splitting data into training and test sets, then normalizing output to be centered around 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, Y_data, test_size=0.15, random_state=42)
norm_train = preprocessing.StandardScaler().fit_transform(y_train)

print "len X train: \n", len(X_train)
print "len Y train: \n", len(y_train)
print "len X test:  \n", len(X_test)
print "len Y test:  \n", len(y_test)

print "\n",len(input_df.columns)-1, "INPUTS"
# Out:
# len X train:
# 13719
# len Y train:
# 13719
# len X test:
# 2422
# len Y test:
# 2422
#
# 97 INPUTS

# %% [markdown]
# #### Feedforward NN

# %%
model = Sequential()
model.add(Dense(60, activation='relu',input_shape=(80,)))
model.add(Dropout(0.25))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='linear'))

#compile the model
# adam = Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
# model.compile(loss='mean_squared_error', optimizer=adam)
rms = RMSprop(lr=0.1, rho=0.9, epsilon=1e-08)
model.compile(loss='mean_squared_logarithmic_error', optimizer=rms)

#train the model
model.fit(X_train, norm_train, batch_size=128, nb_epoch=50, verbose=1)
# Out:
# Epoch 1/50
# 13719/13719 [==============================] - 0s - loss: 0.2491
# Epoch 2/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 3/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 4/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 5/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 6/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 7/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 8/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 9/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 10/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 11/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 12/50
# 13719/13719 [==============================] - 0s - loss: 0.2093
# Epoch 13/50
# ...

# %%
########### NN TRAINING RESULTS ##############

norm_test = preprocessing.StandardScaler().fit_transform(y_test)
predicted = model.predict(X_test) #.reshape(-1)
print "NORMED TEST: ", len(norm_test)
print "PREDICTED: ", len(predicted)
slope, intercept, r_value, p_value, std_err = stats.linregress(norm_test.reshape(-1),predicted.reshape(-1))
print r_value**2

d = {'y_pred': predicted.reshape(-1), 'y_actual': norm_test.reshape(-1)}
res_df = pd.DataFrame(data=d)

sea.set(style="ticks", color_codes=True)
g = sea.JointGrid(predicted.reshape(-1),norm_test.reshape(-1)) #, xlim=(-3,3), ylim=(-3,3))
g = g.plot_joint(plt.scatter, color='#9b59b6', edgecolor="white", alpha='0.1')
# axes = g.axes
# axes.set_xlim(-1,5)
# axes.set_ylim(-1,5)
g.ax_joint.set_xticks([-3, 3, -3,-2,-1,0,1,2,3])
g.ax_joint.set_yticks([-3, 3, -3,-2,-1,0,1,2,3])
sea.plt.show()
# Out:
# NORMED TEST:  2422
# PREDICTED:  2422
# 0.0367511124094

# %%
np.mean([14.00,90.20,90.95,96.27,91.21])
# Out:
# 76.525999999999996
